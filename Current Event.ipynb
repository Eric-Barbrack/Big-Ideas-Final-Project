# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from numpy import random
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("PublicEvents.csv")
frame = ["neighborhood"]
dataFrame = pd.read_csv("PublicEvents.csv", usecols = frame)
dataFrame = dataFrame.dropna()
dataFrame.reset_index(drop=True, inplace=True)
print(dataFrame)
# Out:
#                   neighborhood
# 0                       Uptown
# 1                       Uptown
# 2                     Downtown
# 3                     Downtown
# 4                     Downtown
# 5                     Downtown
# 6                     Downtown
# 7                     Downtown
# 8                   North Side
# 9                Lawrenceville
# 10                    Downtown
# 11                    Downtown
# 12                    Downtown
# 13                    Downtown
# 14                    Downtown
# 15                    Downtown
# 16                    Downtown
# 17                    Downtown
# 18                    Downtown
# 19                    Downtown
# 20                    Downtown
# 21               Hill District
# 22               Hill District
# 23                    Downtown
# 24                    Downtown
# 25                    Downtown
# 26                    Downtown
# 27                   Aspinwall
# 28                    Downtown
# 29                    Downtown
# 30                    Downtown
# 31              Strip District
# 32              Strip District
# 33              Strip District
# 34                    Downtown
# 35                    Downtown
# 36  Northside (East Allegheny)
# 37                    Downtown
# 38                    Downtown
# 39                    Downtown
# 40                    Downtown
# 41                    Downtown
# 42                    Downtown
# 43                    Downtown
# 44                    Downtown
# 45                    Downtown
# 46                    Downtown
# 47                    Downtown
# 48                     Larimer
# 49                  McKeesport
# 50                  South Side
# 51          North Point Breeze
# 52                    Homewood
# 53                  McKeesport
# 54                McKees Rocks
# 55                  Mckeesport
# 56                Mckees Rocks
# 57         Northside (Chateau)
# 58                   Hazelwood
# 59                    Downtown

# %%
hoodDictionary = dict()

for i in range(len(data)):
    hood = str(data.iloc[i][4])
    if(hood in hoodDictionary):
        value = hoodDictionary[hood]
        hoodDictionary[hood] = value + 1
    else:
        hoodDictionary[hood] = 1

print(hoodDictionary)
# Out:
# {'Uptown': 2, 'Downtown': 38, 'North Side': 1, 'Lawrenceville': 1, 'Hill District': 2, 'Aspinwall': 1, 'Strip District': 3, 'Northside (East Allegheny)': 1, 'Larimer': 1, 'McKeesport': 2, 'South Side': 1, 'North Point Breeze': 1, 'Homewood': 1, 'McKees Rocks': 1, 'Mckeesport': 1, 'Mckees Rocks': 1, 'Northside (Chateau)': 1, 'Hazelwood': 1}

# %%
sortedData = dict(sorted(hoodDictionary.items()))

plt.figure(figsize=(20, 10))
plt.bar(sortedData.keys(), sortedData.values())
plt.title("Event Quantity vs Neighborhood")
plt.xlabel("Neighborhood")
plt.xticks(rotation=90)
plt.ylabel("Quantity of Events")
# Out:
# Text(0, 0.5, 'Quantity of Events')

# %% [markdown]
# ### We decided that the more public events in a neighborhood, the better of an area it is. Because of this, Downtown pittsurgh is clearly the best when it comes to this metric. With 38, it beats the strip district with 3.
